# %%
# Import dependencies
import pandas as pd
from pathlib import Path

# %%
# Preview CSV data
data = Path('../Resources/clean_fetal_health.csv')
fetal_df = pd.read_csv(data)
fetal_df.head()
# Out:
#    baseline_FHR_bpm  accelerations  fetal_movement  uterine_contractions  \
# 0             120.0          0.000             0.0                 0.000
# 1             132.0          0.006             0.0                 0.006
# 2             133.0          0.003             0.0                 0.008
# 3             134.0          0.003             0.0                 0.008
# 4             132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolonged_decelerations  \
# 0                0.000                   0.0                      0.0
# 1                0.003                   0.0                      0.0
# 2                0.003                   0.0                      0.0
# 3                0.003                   0.0                      0.0
# 4                0.000                   0.0                      0.0
#
#    abnorm_ST_Var_Perc  mean_ST_Var  abnorm_LT_Var_Perc  ...  FHR_hist_min  \
# ...

# %%
# Set 'A' column as index
fetal_df.reset_index(inplace=True)

# %%
fetal_df.head()
# Out:
#    index  baseline_FHR_bpm  accelerations  fetal_movement  \
# 0      0             120.0          0.000             0.0
# 1      1             132.0          0.006             0.0
# 2      2             133.0          0.003             0.0
# 3      3             134.0          0.003             0.0
# 4      4             132.0          0.007             0.0
#
#    uterine_contractions  light_decelerations  severe_decelerations  \
# 0                 0.000                0.000                   0.0
# 1                 0.006                0.003                   0.0
# 2                 0.008                0.003                   0.0
# 3                 0.008                0.003                   0.0
# 4                 0.008                0.000                   0.0
#
#    prolonged_decelerations  abnorm_ST_Var_Perc  mean_ST_Var  ...  \
# 0                      0.0                73.0          0.5  ...
# 1                      0.0                17.0          2.1  ...
# ...

# %%
# Rename columns using a dictionary
new_column_names = {'index': 'Fetal ID'}
fetal_df = fetal_df.rename(columns = new_column_names)

fetal_df[0:60]
# Out:
#     Fetal ID  baseline_FHR_bpm  accelerations  fetal_movement  \
# 0          0             120.0          0.000           0.000
# 1          1             132.0          0.006           0.000
# 2          2             133.0          0.003           0.000
# 3          3             134.0          0.003           0.000
# 4          4             132.0          0.007           0.000
# 5          5             134.0          0.001           0.000
# 6          6             134.0          0.001           0.000
# 7          7             122.0          0.000           0.000
# 8          8             122.0          0.000           0.000
# 9          9             122.0          0.000           0.000
# 10        10             151.0          0.000           0.000
# 11        11             150.0          0.000           0.000
# 12        12             131.0          0.005           0.072
# 13        13             131.0          0.009           0.222
# ...

# %%
fetal_df = fetal_df.drop(columns = 'fetal_health')

# %%
fetal_df.head()
# Out:
#    Fetal ID  baseline_FHR_bpm  accelerations  fetal_movement  \
# 0         0             120.0          0.000             0.0
# 1         1             132.0          0.006             0.0
# 2         2             133.0          0.003             0.0
# 3         3             134.0          0.003             0.0
# 4         4             132.0          0.007             0.0
#
#    uterine_contractions  light_decelerations  severe_decelerations  \
# 0                 0.000                0.000                   0.0
# 1                 0.006                0.003                   0.0
# 2                 0.008                0.003                   0.0
# 3                 0.008                0.003                   0.0
# 4                 0.008                0.000                   0.0
#
#    prolonged_decelerations  abnorm_ST_Var_Perc  mean_ST_Var  ...  \
# 0                      0.0                73.0          0.5  ...
# ...

# %%
fetal_df.to_json('fetal_data.json', orient='records')
