# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
fetal_df = pd.read_csv(Path('Resources/clean_fetal_health.csv'))

# Review the DataFrame
fetal_df.head()
# Out:
#    baseline_FHR_bpm  accelerations  fetal_movement  uterine_contractions  \
# 0             120.0          0.000             0.0                 0.000
# 1             132.0          0.006             0.0                 0.006
# 2             133.0          0.003             0.0                 0.008
# 3             134.0          0.003             0.0                 0.008
# 4             132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolonged_decelerations  \
# 0                0.000                   0.0                      0.0
# 1                0.003                   0.0                      0.0
# 2                0.003                   0.0                      0.0
# 3                0.003                   0.0                      0.0
# 4                0.000                   0.0                      0.0
#
#    abnorm_ST_Var_Perc  mean_ST_Var  abnorm_LT_Var_Perc  ...  FHR_hist_min  \
# 0                73.0          0.5                43.0  ...          62.0
# 1                17.0          2.1                 0.0  ...          68.0
# 2                16.0          2.1                 0.0  ...          68.0
# 3                16.0          2.4                 0.0  ...          53.0
# 4                16.0          2.4                 0.0  ...          53.0
#
#    FHR_hist_max  FHR_hist_num_peaks  FHR_hist_num_zeroes  FHR_hist_mode  \
# 0         126.0                 2.0                  0.0          120.0
# 1         198.0                 6.0                  1.0          141.0
# 2         198.0                 5.0                  1.0          141.0
# 3         170.0                11.0                  0.0          137.0
# 4         170.0                 9.0                  0.0          137.0
#
#    FHR_hist_mean  FHR_hist_median  FHR_hist_variance  FHR_hist_tendency  \
# 0          137.0            121.0               73.0                1.0
# 1          136.0            140.0               12.0                0.0
# 2          135.0            138.0               13.0                0.0
# 3          134.0            137.0               13.0                1.0
# 4          136.0            138.0               11.0                1.0
#
#    fetal_health
# 0             2
# 1             1
# 2             1
# 3             1
# 4             1
#
# [5 rows x 22 columns]

# %%
# Separate the data into labels and features

y = fetal_df['fetal_health']

# Separate the X variable, the features
x = fetal_df.drop(columns=['fetal_health'])

# %%
y.head()
y.value_counts()
# Out:
# fetal_health
# 1    1655
# 2     295
# 3     176
# Name: count, dtype: int64

# %%
x.head()
# Out:
#    baseline_FHR_bpm  accelerations  fetal_movement  uterine_contractions  \
# 0             120.0          0.000             0.0                 0.000
# 1             132.0          0.006             0.0                 0.006
# 2             133.0          0.003             0.0                 0.008
# 3             134.0          0.003             0.0                 0.008
# 4             132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolonged_decelerations  \
# 0                0.000                   0.0                      0.0
# 1                0.003                   0.0                      0.0
# 2                0.003                   0.0                      0.0
# 3                0.003                   0.0                      0.0
# 4                0.000                   0.0                      0.0
#
#    abnorm_ST_Var_Perc  mean_ST_Var  abnorm_LT_Var_Perc  ...  FHR_hist_width  \
# 0                73.0          0.5                43.0  ...            64.0
# 1                17.0          2.1                 0.0  ...           130.0
# 2                16.0          2.1                 0.0  ...           130.0
# 3                16.0          2.4                 0.0  ...           117.0
# 4                16.0          2.4                 0.0  ...           117.0
#
#    FHR_hist_min  FHR_hist_max  FHR_hist_num_peaks  FHR_hist_num_zeroes  \
# 0          62.0         126.0                 2.0                  0.0
# 1          68.0         198.0                 6.0                  1.0
# 2          68.0         198.0                 5.0                  1.0
# 3          53.0         170.0                11.0                  0.0
# 4          53.0         170.0                 9.0                  0.0
#
#    FHR_hist_mode  FHR_hist_mean  FHR_hist_median  FHR_hist_variance  \
# 0          120.0          137.0            121.0               73.0
# 1          141.0          136.0            140.0               12.0
# 2          141.0          135.0            138.0               13.0
# 3          137.0          134.0            137.0               13.0
# 4          137.0          136.0            138.0               11.0
#
#    FHR_hist_tendency
# 0                1.0
# 1                0.0
# 2                0.0
# 3                1.0
# 4                1.0
#
# [5 rows x 21 columns]

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
# YOUR CODE HERE!
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
logistic_regression_model = LogisticRegression(solver='lbfgs', random_state=1)

# Fit the model using training data
lr_model = logistic_regression_model.fit(X_train, y_train)
# Out:
# C:\Users\sukhr\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Make a prediction using the testing data
test_predictions = logistic_regression_model.predict(X_test)
pd.DataFrame({'Predictions': test_predictions, 'Actual': y_test})
# Out:
#       Predictions  Actual
# 669             1       1
# 1205            1       2
# 870             1       1
# 547             1       2
# 1806            1       1
# ...           ...     ...
# 424             1       2
# 990             1       1
# 0               2       2
# 1149            1       1
# 385             2       1
#
# [532 rows x 2 columns]

# %%
# Generate a confusion matrix for the model
cf_test_matrix = confusion_matrix(y_test, test_predictions)
cf_test_matrix
# Out:
# array([[393,  11,   5],
#        [ 48,  29,   5],
#        [  6,   7,  28]], dtype=int64)

# %%
# Print the classification report for the model
testing_report = classification_report(y_test, test_predictions)
print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.96      0.92       409
#            2       0.62      0.35      0.45        82
#            3       0.74      0.68      0.71        41
#
#     accuracy                           0.85       532
#    macro avg       0.74      0.67      0.69       532
# weighted avg       0.83      0.85      0.83       532
