# %%
import matplotlib.pyplot as plt

# Data for baby ID 45 (replace with your actual data)
feature_names = ['FHR_hist_max', 'FHR_hist_mean', 'FHR_hist_median', 'FHR_hist_min', 'FHR_hist_mode']
feature_values = [200, 112, 117, 50, 116]  # Example values

# Define time points (assuming each feature represents a different time point)
time_points = range(1, len(feature_names) + 1)

# Plot the trend of FHR over time
plt.figure(figsize=(10, 6))
plt.plot(time_points, feature_values, marker='o', linestyle='-', color='b')
plt.title('Trend of Fetal Heart Rate (FHR) over Time')
plt.xlabel('Time Points')
plt.ylabel('FHR Values')
plt.xticks(time_points, feature_names)  # Label x-axis with feature names
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Baby ID 45
baby_id_45_data = {
    'FHR_hist_max': 200,
    'FHR_hist_mean': 112,
    'FHR_hist_median': 117,
    'FHR_hist_min': 50,
    'FHR_hist_mode': 116,
    'FHR_hist_num_peaks': 8,
    'FHR_hist_num_zeroes': 0,
    'FHR_hist_tendency': 0,
    'FHR_hist_variance': 23,
    'FHR_hist_width': 150,
    'abnorm_LT_Var_Perc': 0,
    'abnorm_ST_Var_Perc': 21,
    'accelerations': 0,
    'baseline_FHR_bpm': 122,
    'fetal_movement': 0.02,
    'light_decelerations': 0.006,
    'mean_LT_Var': 15.7,
    'mean_ST_Var': 4.7,
    'prolonged_decelerations': 0,
    'severe_decelerations': 0,
    'uterine_contractions': 0.003
}
# Map predicted fetal health labels to colors
color_map = {'Normal': 'blue', 'Suspect': 'orange', 'Pathology': 'red'}
predicted_fetal_health_color = color_map.get(predicted_fetal_health, 'black')

# Bar Chart
plt.figure(figsize=(10, 6))
plt.bar(baby_id_45_data.keys(), baby_id_45_data.values())
plt.title('Features for Baby ID 45')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.show()

# Scatter Plot (assuming predicted fetal health is available)
# You can replace the 'predicted_fetal_health' with the actual predicted value
predicted_fetal_health = 'Normal'
plt.figure(figsize=(8, 6))
plt.scatter(baby_id_45_data['fetal_movement'], baby_id_45_data['accelerations'], c=predicted_fetal_health)
plt.title('Relationship between fetal_movement and accelerations')
plt.xlabel('fetal_movement')
plt.ylabel('accelerations')
plt.colorbar(label='Predicted Fetal Health')
plt.show()

# Histogram
plt.figure(figsize=(10, 6))
plt.hist(baby_id_45_data['FHR_hist_max'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of FHR_hist_max')
plt.xlabel('FHR_hist_max')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Line Chart
plt.figure(figsize=(10, 6))
plt.plot(['FHR_hist_max', 'FHR_hist_mean', 'FHR_hist_median', 'FHR_hist_min', 'FHR_hist_mode'],
         [baby_id_45_data['FHR_hist_max'], baby_id_45_data['FHR_hist_mean'], baby_id_45_data['FHR_hist_median'],
          baby_id_45_data['FHR_hist_min'], baby_id_45_data['FHR_hist_mode']],
         marker='o')
plt.title('Fetal Heart Rate Trends for Baby ID 45')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_axes.py:4433, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4432 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4433     colors = mcolors.to_rgba_array(c)
#    4434 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\envs\dev\lib\site-packages\matplotlib\colors.py:471, in to_rgba_array(c, alpha)
#     470 if isinstance(c, str):
# --> 471     raise ValueError(f"{c!r} is not a valid color value.")
#     473 if len(c) == 0:
#
# ValueError: 'Normal' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 44
#      42 predicted_fetal_health = 'Normal'
# ...
