# %%
# Import dependencies
import pandas as pd
import sqlite3
import numpy as np
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm  
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
# Connect to the SQLite database
conn = sqlite3.connect("../Resources/fetal_health_CTG_data.db")

# Query to select all data from the table
query = "SELECT * FROM fetal_health_CTG_data"

# Read data from the database into a DataFrame
fetal_df= pd.read_sql_query(query, conn)

# Close the connection
conn.close()

# %%
# Display the DataFrame
fetal_df.head()
# Out:
#    baseline_FHR_bpm  accelerations  fetal_movement  uterine_contractions  \
# 0             120.0          0.000             0.0                 0.000
# 1             132.0          0.006             0.0                 0.006
# 2             133.0          0.003             0.0                 0.008
# 3             134.0          0.003             0.0                 0.008
# 4             132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolonged_decelerations  \
# 0                0.000                   0.0                      0.0
# 1                0.003                   0.0                      0.0
# 2                0.003                   0.0                      0.0
# 3                0.003                   0.0                      0.0
# 4                0.000                   0.0                      0.0
#
#    abnorm_ST_Var_Perc  mean_ST_Var  abnorm_LT_Var_Perc  ...  FHR_hist_min  \
# 0                73.0          0.5                43.0  ...          62.0
# 1                17.0          2.1                 0.0  ...          68.0
# 2                16.0          2.1                 0.0  ...          68.0
# 3                16.0          2.4                 0.0  ...          53.0
# 4                16.0          2.4                 0.0  ...          53.0
#
#    FHR_hist_max  FHR_hist_num_peaks  FHR_hist_num_zeroes  FHR_hist_mode  \
# 0         126.0                 2.0                  0.0          120.0
# 1         198.0                 6.0                  1.0          141.0
# 2         198.0                 5.0                  1.0          141.0
# 3         170.0                11.0                  0.0          137.0
# 4         170.0                 9.0                  0.0          137.0
#
#    FHR_hist_mean  FHR_hist_median  FHR_hist_variance  FHR_hist_tendency  \
# 0          137.0            121.0               73.0                1.0
# 1          136.0            140.0               12.0                0.0
# 2          135.0            138.0               13.0                0.0
# 3          134.0            137.0               13.0                1.0
# 4          136.0            138.0               11.0                1.0
#
#    fetal_health
# 0             2
# 1             1
# 2             1
# 3             1
# 4             1
#
# [5 rows x 22 columns]

# %%
#check the value counts of fetal health
health_status_ct=fetal_df["fetal_health"].value_counts()
health_status_ct
# Out:
# fetal_health
# 1    1655
# 2     295
# 3     176
# Name: count, dtype: int64

# %%
fetal_df.corr()
# Out:
#                          baseline_FHR_bpm  accelerations  fetal_movement  \
# baseline_FHR_bpm                 1.000000      -0.080560       -0.033436
# accelerations                   -0.080560       1.000000        0.048235
# fetal_movement                  -0.033436       0.048235        1.000000
# uterine_contractions            -0.146373       0.089674       -0.068779
# light_decelerations             -0.159032      -0.108615        0.049228
# severe_decelerations            -0.053518      -0.043018       -0.010976
# prolonged_decelerations         -0.104597      -0.127749        0.265922
# abnorm_ST_Var_Perc               0.305570      -0.279577       -0.103715
# mean_ST_Var                     -0.279607       0.207170        0.121314
# abnorm_LT_Var_Perc               0.285630      -0.373943       -0.074096
# mean_LT_Var                     -0.032091      -0.142363        0.011047
# FHR_hist_width                  -0.147679       0.298631        0.162790
# FHR_hist_min                     0.361619      -0.154286       -0.153917
# FHR_hist_max                     0.275110       0.394147        0.099853
# FHR_hist_num_peaks              -0.113933       0.190452        0.164654
# FHR_hist_num_zeroes             -0.004745      -0.006147       -0.017749
# FHR_hist_mode                    0.708993       0.243610       -0.061192
# FHR_hist_mean                    0.723121       0.270334       -0.089671
# FHR_hist_median                  0.789246       0.272849       -0.072329
# FHR_hist_variance               -0.133938       0.125704        0.179340
# FHR_hist_tendency                0.293503       0.028420       -0.001541
# fetal_health                     0.148151      -0.364066        0.088010
#
#                          uterine_contractions  light_decelerations  \
# baseline_FHR_bpm                    -0.146373            -0.159032
# accelerations                        0.089674            -0.108615
# fetal_movement                      -0.068779             0.049228
# uterine_contractions                 1.000000             0.285079
# light_decelerations                  0.285079             1.000000
# severe_decelerations                 0.006788             0.107573
# prolonged_decelerations              0.077036             0.225611
# abnorm_ST_Var_Perc                  -0.232811            -0.119152
# mean_ST_Var                          0.289679             0.562170
# abnorm_LT_Var_Perc                  -0.306608            -0.271282
# mean_LT_Var                         -0.066058            -0.242932
# FHR_hist_width                       0.142541             0.520467
# FHR_hist_min                        -0.113323            -0.553534
# FHR_hist_max                         0.122766             0.218043
# FHR_hist_num_peaks                   0.082693             0.397620
# FHR_hist_num_zeroes                  0.057894             0.235296
# FHR_hist_mode                       -0.104854            -0.347233
# FHR_hist_mean                       -0.187505            -0.527354
# FHR_hist_median                     -0.140287            -0.388586
# FHR_hist_variance                    0.238582             0.564289
# FHR_hist_tendency                   -0.072314             0.000072
# fetal_health                        -0.204894             0.058870
#
#                          severe_decelerations  prolonged_decelerations  \
# baseline_FHR_bpm                    -0.053518                -0.104597
# accelerations                       -0.043018                -0.127749
# fetal_movement                      -0.010976                 0.265922
# uterine_contractions                 0.006788                 0.077036
# light_decelerations                  0.107573                 0.225611
# severe_decelerations                 1.000000                 0.012395
# prolonged_decelerations              0.012395                 1.000000
# abnorm_ST_Var_Perc                   0.033949                 0.046226
# mean_ST_Var                          0.034130                 0.267011
# abnorm_LT_Var_Perc                  -0.030770                -0.137333
# mean_LT_Var                         -0.037667                -0.226514
# FHR_hist_width                       0.044880                 0.265391
# FHR_hist_min                        -0.071974                -0.276764
# FHR_hist_max                        -0.021135                 0.120221
# FHR_hist_num_peaks                   0.007024                 0.222860
# FHR_hist_num_zeroes                  0.043441                 0.056423
# FHR_hist_mode                       -0.215161                -0.436416
# FHR_hist_mean                       -0.158673                -0.488663
# FHR_hist_median                     -0.160451                -0.444778
# FHR_hist_variance                    0.136421                 0.503301
# FHR_hist_tendency                   -0.070483                -0.215405
# fetal_health                         0.131934                 0.484859
#
#                          abnorm_ST_Var_Perc  mean_ST_Var  abnorm_LT_Var_Perc  \
# baseline_FHR_bpm                   0.305570    -0.279607            0.285630
# accelerations                     -0.279577     0.207170           -0.373943
# fetal_movement                    -0.103715     0.121314           -0.074096
# uterine_contractions              -0.232811     0.289679           -0.306608
# light_decelerations               -0.119152     0.562170           -0.271282
# severe_decelerations               0.033949     0.034130           -0.030770
# prolonged_decelerations            0.046226     0.267011           -0.137333
# abnorm_ST_Var_Perc                 1.000000    -0.430705            0.459413
# mean_ST_Var                       -0.430705     1.000000           -0.470259
# abnorm_LT_Var_Perc                 0.459413    -0.470259            1.000000
# mean_LT_Var                       -0.315105     0.073892           -0.171114
# FHR_hist_width                    -0.260463     0.660847           -0.451297
# FHR_hist_min                       0.275378    -0.622569            0.422834
# FHR_hist_max                      -0.111806     0.409072           -0.283183
# FHR_hist_num_peaks                -0.167561     0.501430           -0.279301
# FHR_hist_num_zeroes               -0.149296     0.266183           -0.121784
# FHR_hist_mode                      0.058363    -0.307586            0.165211
# FHR_hist_mean                      0.074554    -0.445401            0.222321
# FHR_hist_median                    0.119960    -0.336109            0.186480
# FHR_hist_variance                 -0.146434     0.555852           -0.281536
# FHR_hist_tendency                 -0.005748    -0.066140            0.042481
# fetal_health                       0.471191    -0.103382            0.426146
#
#                          ...  FHR_hist_min  FHR_hist_max  FHR_hist_num_peaks  \
# baseline_FHR_bpm         ...      0.361619      0.275110           -0.113933
# accelerations            ...     -0.154286      0.394147            0.190452
# fetal_movement           ...     -0.153917      0.099853            0.164654
# uterine_contractions     ...     -0.113323      0.122766            0.082693
# light_decelerations      ...     -0.553534      0.218043            0.397620
# severe_decelerations     ...     -0.071974     -0.021135            0.007024
# prolonged_decelerations  ...     -0.276764      0.120221            0.222860
# abnorm_ST_Var_Perc       ...      0.275378     -0.111806           -0.167561
# mean_ST_Var              ...     -0.622569      0.409072            0.501430
# abnorm_LT_Var_Perc       ...      0.422834     -0.283183           -0.279301
# mean_LT_Var              ...     -0.144976      0.002023            0.056357
# FHR_hist_width           ...     -0.898519      0.690769            0.747071
# FHR_hist_min             ...      1.000000     -0.303286           -0.670287
# FHR_hist_max             ...     -0.303286      1.000000            0.517652
# FHR_hist_num_peaks       ...     -0.670287      0.517652            1.000000
# FHR_hist_num_zeroes      ...     -0.306567      0.183766            0.288593
# FHR_hist_mode            ...      0.353067      0.235877           -0.100123
# FHR_hist_mean            ...      0.486121      0.191108           -0.217242
# FHR_hist_median          ...      0.400191      0.292680           -0.122844
# FHR_hist_variance        ...     -0.545091      0.439094            0.454354
# FHR_hist_tendency        ...     -0.242579     -0.143111            0.110114
# fetal_health             ...      0.063175     -0.045265           -0.023666
#
#                          FHR_hist_num_zeroes  FHR_hist_mode  FHR_hist_mean  \
# baseline_FHR_bpm                   -0.004745       0.708993       0.723121
# accelerations                      -0.006147       0.243610       0.270334
# fetal_movement                     -0.017749      -0.061192      -0.089671
# uterine_contractions                0.057894      -0.104854      -0.187505
# light_decelerations                 0.235296      -0.347233      -0.527354
# severe_decelerations                0.043441      -0.215161      -0.158673
# prolonged_decelerations             0.056423      -0.436416      -0.488663
# abnorm_ST_Var_Perc                 -0.149296       0.058363       0.074554
# mean_ST_Var                         0.266183      -0.307586      -0.445401
# abnorm_LT_Var_Perc                 -0.121784       0.165211       0.222321
# mean_LT_Var                         0.123869       0.072071       0.137813
# FHR_hist_width                      0.317276      -0.159261      -0.280846
# FHR_hist_min                       -0.306567       0.353067       0.486121
# FHR_hist_max                        0.183766       0.235877       0.191108
# FHR_hist_num_peaks                  0.288593      -0.100123      -0.217242
# FHR_hist_num_zeroes                 1.000000      -0.057978      -0.084417
# FHR_hist_mode                      -0.057978       1.000000       0.893412
# FHR_hist_mean                      -0.084417       0.893412       1.000000
# FHR_hist_median                    -0.052896       0.933399       0.948251
# FHR_hist_variance                   0.196747      -0.312765      -0.399423
# FHR_hist_tendency                   0.084694       0.415564       0.327076
# fetal_health                       -0.016682      -0.250412      -0.226985
#
#                          FHR_hist_median  FHR_hist_variance  \
# baseline_FHR_bpm                0.789246          -0.133938
# accelerations                   0.272849           0.125704
# fetal_movement                 -0.072329           0.179340
# uterine_contractions           -0.140287           0.238582
# light_decelerations            -0.388586           0.564289
# severe_decelerations           -0.160451           0.136421
# prolonged_decelerations        -0.444778           0.503301
# abnorm_ST_Var_Perc              0.119960          -0.146434
# mean_ST_Var                    -0.336109           0.555852
# abnorm_LT_Var_Perc              0.186480          -0.281536
# mean_LT_Var                     0.063228          -0.164079
# FHR_hist_width                 -0.168854           0.615884
# FHR_hist_min                    0.400191          -0.545091
# FHR_hist_max                    0.292680           0.439094
# FHR_hist_num_peaks             -0.122844           0.454354
# FHR_hist_num_zeroes            -0.052896           0.196747
# FHR_hist_mode                   0.933399          -0.312765
# FHR_hist_mean                   0.948251          -0.399423
# FHR_hist_median                 1.000000          -0.294105
# FHR_hist_variance              -0.294105           1.000000
# FHR_hist_tendency               0.389210          -0.078013
# fetal_health                   -0.205033           0.206630
#
#                          FHR_hist_tendency  fetal_health
# baseline_FHR_bpm                  0.293503      0.148151
# accelerations                     0.028420     -0.364066
# fetal_movement                   -0.001541      0.088010
# uterine_contractions             -0.072314     -0.204894
# light_decelerations               0.000072      0.058870
# severe_decelerations             -0.070483      0.131934
# prolonged_decelerations          -0.215405      0.484859
# abnorm_ST_Var_Perc               -0.005748      0.471191
# mean_ST_Var                      -0.066140     -0.103382
# abnorm_LT_Var_Perc                0.042481      0.426146
# mean_LT_Var                       0.153093     -0.226797
# FHR_hist_width                    0.118152     -0.068789
# FHR_hist_min                     -0.242579      0.063175
# FHR_hist_max                     -0.143111     -0.045265
# FHR_hist_num_peaks                0.110114     -0.023666
# FHR_hist_num_zeroes               0.084694     -0.016682
# FHR_hist_mode                     0.415564     -0.250412
# FHR_hist_mean                     0.327076     -0.226985
# FHR_hist_median                   0.389210     -0.205033
# FHR_hist_variance                -0.078013      0.206630
# FHR_hist_tendency                 1.000000     -0.131976
# fetal_health                     -0.131976      1.000000
#
# [22 rows x 22 columns]

# %%
# Calculate the correlation matrix
correlation_matrix = fetal_df.corr()

# Extract the correlation coefficients of features with the target variable
correlation_with_target = correlation_matrix["fetal_health"].sort_values(ascending=False)

# Print the correlation coefficients
print(correlation_with_target)
# Out:
# fetal_health               1.000000
# prolonged_decelerations    0.484859
# abnorm_ST_Var_Perc         0.471191
# abnorm_LT_Var_Perc         0.426146
# FHR_hist_variance          0.206630
# baseline_FHR_bpm           0.148151
# severe_decelerations       0.131934
# fetal_movement             0.088010
# FHR_hist_min               0.063175
# light_decelerations        0.058870
# FHR_hist_num_zeroes       -0.016682
# FHR_hist_num_peaks        -0.023666
# FHR_hist_max              -0.045265
# FHR_hist_width            -0.068789
# mean_ST_Var               -0.103382
# FHR_hist_tendency         -0.131976
# uterine_contractions      -0.204894
# FHR_hist_median           -0.205033
# mean_LT_Var               -0.226797
# FHR_hist_mean             -0.226985
# FHR_hist_mode             -0.250412
# accelerations             -0.364066
# Name: fetal_health, dtype: float64

# %%
# Define threshold for correlation coefficients
threshold = 0.3

# Create a list of tuples containing variable names and their correlations with the target variable,
# filtering out variables with correlations below the threshold
variables_with_correlation = [(variable, correlation) for variable, correlation in correlation_with_target.items()
                               if abs(correlation) >= threshold]

# Print the list of variables with their correlations
for variable, correlation in variables_with_correlation:
    print(f'{variable}: {correlation}')
# Out:
# fetal_health: 1.0
# prolonged_decelerations: 0.48485918632134756
# abnorm_ST_Var_Perc: 0.4711907528466762
# abnorm_LT_Var_Perc: 0.42614641992406366
# accelerations: -0.36406579288786295

# %% [markdown]
# The feature showing the relatively strong correlation with fetal health is prolonged decelerations. There are moderate correlations also observed between fetal health and abnormal short term variability, as well as fetal health and percentage of time with abnormal long term variability.

# %%
#Scatter plot
from scipy.stats import linregress

x_values = fetal_df ["prolonged_decelerations"]
y_values=fetal_df["fetal_health"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,2.2),fontsize=15,color="red")
plt.xlabel("Prolonged_decelerations")
plt.ylabel("Fetal_health_Status")
plt.title("Prolonged_decelerations and Fetal Health")
print(f"correlation coefficient : {round(rvalue,2)}")
print(f"The r squared value is :{round(rvalue**2,2)}")

plt.show()
# Out:
# correlation coefficient : 0.48
# The r squared value is :0.24

# %% [markdown]
# This lineplot clearly shows the relationship between prolonged decelerations of fetal heart rate and fetal health outcome. The longer amount of time observed with prolonged decelerations, the more at-risk the health outcome was likely to be.

# %%
# Select the variables for plotting
y_variable = "prolonged_decelerations"
x_variable = "fetal_health"


# Replace numeric class labels with text labels
fetal_df["fetal_health"] = fetal_df["fetal_health"]

# Create a scatter plot
plt.figure(figsize=(5,5))
plt.bar(fetal_df[x_variable], fetal_df[y_variable], alpha=0.5)
plt.title("Fetal Health Status vs Prolonged Decelerations")
plt.xlabel("Fetal health status")
plt.ylabel("Prolonged Decelerations")
plt.grid(True)
plt.show()

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming you have a DataFrame df with relevant data
# # df should contain columns for the features mentioned in the feature-importance pairs
# # and a column for class labels

# # Sample feature-importance pairs
# feature_importances = [
#     (0.276902387649442, 'abnorm_LT_Var_Perc'),
#     (0.2572591064690467, 'abnorm_ST_Var_Perc'),
#     (0.17812365241379596, 'FHR_hist_mean')
# ]

# # Extract feature names
# feature_names = [pair[1] for pair in feature_importances]

# # Assuming df contains columns for features and a column for class labels
# # Assuming class labels are in a column named "class"

# # Create histograms for each feature, segmented by class
# for feature in feature_names:
#     plt.figure(figsize=(8, 6))
#     sns.histplot(data=fetal_df, x=feature, hue="fetal_health", multiple="stack", bins=20, kde=True)
#     plt.title(f"Histogram of {feature} Based on Various Classes")
#     plt.xlabel(feature)
#     plt.ylabel("Frequency")
#     plt.legend(title="Class")
#     plt.show()

# %%
# Select the variables for plotting
y_variable = "prolonged_decelerations"
x_variable = "fetal_health"

# Replace numeric class labels with text labels
#fetal_df["fetal_health"] = fetal_df["fetal_health"].map({1: 'Normal', 2: 'Suspect', 3: 'Pathology'})

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(fetal_df[x_variable], fetal_df[y_variable], alpha=0.5)
plt.title("Fetal Health Status vs Prolonged Decelerations")
plt.xlabel("Fetal Health Status")
plt.ylabel("Prolonged Decelerations")
plt.grid(True)

# Set custom tick labels for the x-axis
plt.xticks([1, 2, 3], ['Normal', 'Suspect', 'Pathology'])

plt.show()

# %%
# Select the variables for plotting
y_variable = "prolonged_decelerations"
x_variable = "fetal_health"

# Define custom colors for each category
colors = {1: "green", 2: "orange", 3: "blue"}

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(fetal_df[x_variable], fetal_df[y_variable], alpha=0.5, color=[colors[label] for label in fetal_df[x_variable]])
plt.title("Fetal Health Status vs Prolonged Decelerations")
plt.xlabel("Fetal Health Status")
plt.ylabel("Prolonged Decelerations")
plt.grid(True)

# Set custom tick labels for the x-axis
plt.xticks([1, 2, 3], ['Normal', 'Suspect', 'Pathology'])

plt.show()
